# %% [markdown]
# # Music machine learning - Neural networks
#
# ### Author: Philippe Esling (esling@ircam.fr)
#
# In this course we will cover
# 1. A [quick introduction](#intro) on the code that we will adress and auxiliary functions
# 2. A simple implementation for a [single neuron](#single)
# 3. An implementation of [regression](#implem) using scikit-learn
# 4. Some [common good practices](#practices) in machine learning

# %% [markdown]
# # Introducing neural networks

# %% [markdown]
# In this tutorial, we will cover a more advanced classification algorithm through the use of *neural networks*. The tutorial starts by performing a simple **single neuron** discrimination of two random distributions. Then, we will study the typical **XOR problem** by using a more advanced 2-layer **perceptron**. Finally, we generalize the use of neural networks in order to perform classification on a given set of audio files.

# %% [markdown]
# We are going to use relatively _low-level_ libraries to perform the first exercises (implementing your own neurons)

# %%
import time
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# To simplify your work, we provide a first set of functions that provides simple plotting functionnalities (from the `helper_plot.py` file)
#
#   |**File**|*Explanation*|
#   |-------:|:---------|
#   |`plot_boundary`|Plots the decision boundary of a single neuron with 2-dimensional inputs|
#   |`plot_patterns`|Plots (bi-dimensionnal) input patterns|

# %%
from helper_plot import plot_boundary
from helper_plot import plot_patterns

# %% [markdown]
# Remember that a single neuron is only able to learn _linearly separable_ problems. To produce such classes of problems, we provide a script that draw a set of random 2-dimensional points, then choose a random line in this space that will act as the linear frontier between 2 classes (hence defining a linear 2-class problem). The variables that will be used by your code are the following.
#
# ```Matlab
# desired       % classes of the patterns
# inputs        % 2 x n final matrix of random input patterns
# weights       % 2 x 1 vector of neuron weights
# bias          % 1 x 1 vector of bias
# ```
#
# You can execute the code below to see our simple classification problem. (Note that running the same cell multiple times produces a different starting dataset).

# %%
# Number of points to generate
nPats = 100 + np.floor(np.random.rand() * 30)

# Generate 2-dimensional random points
patterns = np.random.rand(2, int(nPats)) * 2 - 1

# Slope of separating line
slope = np.log(np.random.rand() * 10)
yint = np.random.rand() * 2 - 1

# Create the indexes for a two-class problem
desired = (patterns[1,:] - patterns[0,:] * slope - yint > 0) * 1

# Plot the corresponding pattern
fig = plot_patterns(patterns,desired)

# %% [markdown]
# ## Single neuron
#
# For the first parts of the tutorial, we will perform the simplest classification model possible in a neural network setting, a single neuron. We briefly recall here that; given an input vector $ \mathbf{x} \in \mathbb{R}^{n} $, a single neuron computes the function
#
# $$
# \begin{equation}
# \hat{y}=\phi\left(\sum_{i = 1}^{n}w_{i}.x_{i} + b\right)
# \label{eq1}
# \end{equation}
# $$
#
# with $ \mathbf{w} \in \mathbb{R}^{n} $ a weight vector, $ b $ a bias and $ \phi\left(\cdot\right) $ an *activation function*. Therefore, if we consider the *threshold* activation function ($ \phi_{0}\left(x\right)=1 $ if $ x \geq 0$), a single neuron simply performs an *affine transform* and then a *linear* discrimination of the space. A network will be composed of _layers_ of these neurons, which produce successive computations
#
# <img src="images/02_feedforward_nn.png" align="center"/>
#
# Geometrically, a single neuron computes an hyperplane that separates the space. In order to learn, we have to adjust the weights and know "how much wrong we are". To do so, we consider that we know the desired output $ d $ of a system for a given example $ \mathbf{x} $ (eg. a predicted value for a regression system, a class value for a classification system). Therefore, we define the loss function $ \mathcal{L}_{\mathcal{D}} $ over a whole dataset as
#
# $$
# \begin{equation}
# \mathcal{L}_{\mathcal{D}}=\sum_{j=1}^{k_{\mathcal{D}}}\left\Vert y_{j}-\hat{y}_{j}\right\Vert ^{2}
# \label{eq2}
# \end{equation}
# $$
#
# In order to know how to change the weights based on the value of the errors, we need to now "how to change it to make it better". Therefore, we should compute the sets of derivatives of the error given each parameter
#
# $$
# \begin{equation}
# \Delta\bar{\mathbf{w}}=\left(\frac{\delta\mathcal{L}}{\delta w_{1}},\ldots,\frac{\delta\mathcal{L}}{\delta w_{n}}\right)
# \label{eq3}
# \end{equation}
# $$
#
# ***
#
# **Exercise**
#
#   1. Perform the derivatives of the output given a single neuron
#   2. Perform the derivatives for the bias as well
#
# ***

# %% [markdown]
# ### Training your own neuron
#
# We will start by training a single neuron to learn how to perform this discrimination with a linear problem (so that a single neuron is enough to solve it).

# %%
# Inputs to use
inputs = patterns

# Initialize the weights
weights = np.random.randn(1, 2)
bias = np.random.randn(1, 1)

# Learning rate
eta = 0.05

# Weight decay
lambdaW = 0

# Sum-squared error limit
TSS_Limit = 0.1

# %% [markdown]
# ***
# The derivative of a single neuron is given by the equation below:
#
# Weight:
# $$
# \begin{equation}
# \frac{\delta\mathcal{L}}{\delta w_{1}} = \frac{\delta\mathcal{L}}{\delta \hat{y}}.\frac{\delta\mathcal{\hat{y}}}{\delta \mathcal{O_{1}}}.\frac{\delta\mathcal{O_{1}}}{\delta w_{1}}
# \label{eq4} = 2  \cdot (y_{j} - \hat{y_{j}}) \cdot x
# \end{equation}
# $$
#
# Bias:
# $$
# \begin{equation}
# \frac{\delta\mathcal{L}}{\delta b_{1}} = \frac{\delta\mathcal{L}}{\delta \hat{y}}.\frac{\delta\mathcal{\hat{y}}}{\delta \mathcal{O_{1}}}.\frac{\delta\mathcal{O_{1}}}{\delta b_{1}}
# \label{eq5} = 2  \cdot (y_{j} - \hat{y_{j}})
# \end{equation}
# $$
#
# ***

# %%
# Activation function that correspond to: phi(x) = 1 if x >= 0, else 0
def activation(x):
    return np.where(x >= 0, 1, 0)

# Output of the neuron
output = activation(np.dot(weights, inputs) + bias)

# Derivative of w and b
dw = np.dot((desired - output), inputs.T) + lambdaW * weights
db = np.mean(desired - output)

# %% [markdown]
# Now you need to update the following code loop to ensure that your neuron learns to separate between the classes
# ***
#
# **Exercise**
#   1. Update the loop so that it computes the forward propagation error
#   2. Update the loop to perform learning (based on back-propagation)
#   3. Run the learning procedure, which should produce a result similar to that displayed on the website
#   4. Perform multiple re-runs by **tweaking the hyperparameters** (learning rate, weight decay)
#   5. What observations can you make on the learning process?
#   6. (Optional) Change the input patterns, and confirm your observations.
#   6. (Optional) Incorporate the bias in the weights to obtain a **vectorized** code.
#
# ***

# %%
# Plot the corresponding pattern
fig = plot_patterns(patterns,desired)
plt.draw()

# Update loop
for i in range(100):
    
    # Forward propagation
    output = activation(np.dot(weights, inputs) + bias)
    TSS = np.sum(np.power(np.abs(desired - output), 2)) + lambdaW * np.sum(np.power(weights,2))
    
    # Backpropagation
    dw = np.dot((desired - output), inputs.T) + 2 * lambdaW * weights
    db = np.mean(desired - output)
    
    # Update weights and bias
    weights += eta * dw
    bias += eta * db
    
    print('%2d.  weights = %f, %f, %f, %f' % (i, bias[0, 0], weights[0, 0], weights[0, 1], TSS))
    plot_boundary(np.concatenate((bias, weights), axis=1), i, '--', fig)
    plt.draw()
    time.sleep(0.2)
    if TSS < TSS_Limit:
        break
    
plot_boundary(np.concatenate((bias, weights), axis=1), i, '-', fig);
# Out:
#  0.  weights = -0.786264, -0.403227, 1.437912, 72.000000
#  1.  weights = -0.777020, -1.530886, 0.999822, 36.000000
#  2.  weights = -0.771558, -1.877565, 0.880163, 13.000000
#  3.  weights = -0.768617, -1.995268, 0.911885, 7.000000
#  4.  weights = -0.766936, -2.050775, 0.950648, 4.000000
#  5.  weights = -0.765676, -2.105250, 0.950051, 3.000000
#  6.  weights = -0.764836, -2.121956, 0.991350, 2.000000
#  7.  weights = -0.764415, -2.132906, 1.005187, 1.000000
#  8.  weights = -0.763995, -2.143856, 1.019024, 1.000000
#  9.  weights = -0.763575, -2.154807, 1.032861, 1.000000
# 10.  weights = -0.762735, -2.203525, 1.004802, 2.000000
# 11.  weights = -0.762314, -2.214475, 1.018639, 1.000000
# 12.  weights = -0.762314, -2.214475, 1.018639, 0.000000

# %% [markdown]
# ***
# By tweaking the learning rate, we clearly see that a higher learning rate is faster to converge (if it converges), but can easily diverge. Whereas with a small learning rate, it does not diverge, but takes longer to reach the right value.
# Therefore, it is necessary to take care to this value if we want to optimize the performance of a neural network.
#
# By modifying the input pattern, we obtain the same result.
# ***

# %% [markdown]
# #### Second method to update the loop

# %%
# Plot the corresponding pattern
fig = plot_patterns(patterns,desired)
plt.draw()

# Update loop
for i in range(20):
    
    for idj, inputs_j in enumerate(inputs.T):
        
        # Forward propagation
        output = activation(np.dot(weights, inputs_j) + bias)

        # Backpropagation
        dw = (desired[idj] - output) * inputs_j + lambdaW * weights
        db = desired[idj] - output

        # Update weights and bias
        weights += eta * dw
        bias += eta * db

    print('%2d.  weights = %f, %f, %f' % (i, bias[0, 0], weights[0, 0], weights[0, 1]))
    plot_boundary(np.concatenate((bias, weights), axis=1), i, '--', fig)
    plt.draw()
    time.sleep(0.2)
    
plot_boundary(np.concatenate((bias, weights), axis=1), i, '-', fig);
# Out:
#  0.  weights = 0.214729, -1.175726, 0.551490
#  1.  weights = 0.214729, -1.209708, 0.567430
#  2.  weights = 0.214729, -1.244671, 0.583830
#  3.  weights = 0.214729, -1.280646, 0.600704
#  4.  weights = 0.264729, -1.308094, 0.620635
#  5.  weights = 0.264729, -1.345901, 0.638573
#  6.  weights = 0.264729, -1.384801, 0.657029
#  7.  weights = 0.264729, -1.424826, 0.676019
#  8.  weights = 0.264729, -1.466007, 0.695558
#  9.  weights = 0.264729, -1.508379, 0.715661
# 10.  weights = 0.264729, -1.551975, 0.736346
# 11.  weights = 0.264729, -1.596831, 0.757628
# 12.  weights = 0.314729, -1.633418, 0.782094
# 13.  weights = 0.314729, -1.680628, 0.804699
# 14.  weights = 0.314729, -1.729203, 0.827957
# 15.  weights = 0.314729, -1.779181, 0.851887
# 16.  weights = 0.314729, -1.830604, 0.876509
# 17.  weights = 0.314729, -1.883514, 0.901842
# 18.  weights = 0.364729, -1.928386, 0.930476
# 19.  weights = 0.364729, -1.984122, 0.957370

# %% [markdown]
# ### 2-layer XOR problem
#
# In most cases, classification problems are far from being linear. Therefore, we need more advanced methods to be able to compute non-linear class boundaries. The advantage of neural networks is that the same principle can be applied in a *layer-wise* fashion. This allows to further discriminate the space in sub-regions (as seen in the course). We will try to implement the 2-layer *perceptron* that can provide a solution to the infamous XOR problem. The idea is now to have the output of the first neurons to be connected to a set of other neurons. Therefore, if we take back our previous formulation, we have the same output for the first neuron(s) $\hat{y}$, that we will now term as $y^{(1)}$. Then, we feed these outputs to a second layer of neurons, which gives
#
#
# $$
# \begin{equation}
# y^{(2)}=\phi\left(\sum_{i = 1}^{n}w_{i}.y^{(1)}_{i} + b\right)
# \label{eq6}
# \end{equation}
# $$
#
# Finally, we will rely on the same loss $\mathcal{L_{D}}$ as in the previous exercise, but the outputs used are $y_2$ instead of $y$. As in the previous case, we now need to compute the derivatives of the weights and biases for several layers . However, you should see that some form of generalization might be possible for any number of layer.

# %% [markdown]
# ***
#
# **Exercise**
#   1. Perform the derivatives for the last layer specifically
#   2. Define a generalized derivative for any previous layer
#
# ***

# %% [markdown]
# We can construct the prototypical set of XOR values by using the following code (note that this is the most simple case, but still this is typically a problem that cannot be solved by a _linear classifier_

# %%
patterns = np.array([[-1, -1],[-1,  1],[1, -1],[1,  1]]).transpose() # Input patterns
desired = np.array([0, 1, 1, 0])                       # Corresponding classes

# Initialize based on their sizes
nInputs = patterns.shape[0]
nOutputs = 1
nPat = patterns.shape[1]

# First plot the patterns
fig = plot_patterns(patterns, desired)


# 1- derivatives for the last layer
# output = sigmoid(np.dot(weights2, y1) + bias2)
# output_layer1 = sigmoid(np.dot(weights1, inputs) + bias1)

# dw_last = dloss * dactivation_output * doutput (output_layer1)
# dw_previous = dloss * dactivation_output * weights_output * dactivation_previous * doutput_previous (x, if just 2 layer)
# dw_previous_previous = dloss * dactivation_output * weights_output * dactivation_previous * weights_output_previous * dactivation_previous_previous * doutput_previous_previous (x)

# %% [markdown]
# The variables that will be used by your code are the following.
#
# ```Matlab
# patterns          % 2 x n matrix of random points
# desired           % classes of the patterns
# inputs1           % 3 x n final matrix of inputs (accounting for bias)
# nHiddens          % Number of hidden units
# learnRate         % Learning rate parameter
# momentum          % Momentum parameter (bonus)
# weights1          % 1st layer weights
# weights2          % 2nd layer weights
# TSS_Limit         % Sum-squared error limit
# ```

# %%
nHiddens = 2           # Number of hidden units
learnRate = 0.001       # Learning rate parameter
momentum = 0.1         # Momentum parameter

# Overall input patterns
inputs = patterns

# Sum-squared error limit
TSS_Limit = 0.4

# Learning rate
eta = 0.01

# %% [markdown]
# ***
#
# **Exercise**
#
#   1. Update the forward propagation and error computation (compared to desired).
#   2. Update the back-propagation part to learn the weights of both layers.
#   3. Run the learning, which should produce a result similar to that displayed below.
#   4. Perform multiple re-runs of the learning procedure (re-launching with different initializations)
#   5. What observations can you make on the learning process?
#   6. What happens if you initialize all weights to zeros?
#   7. (Optional) Implement the *sparsity* constraint in your neural network.
#   7. (Optional) Implement the *weight decay* constraint in your network.
#   7. (Optional) Add the *momentum* to the learning procedure.
#
# *For optional questions, please look after the first code box for more information*
#
# ***

# %%
# Weights of first and second layer
weights1 = (np.random.randn(nHiddens, nInputs) - 0.5)      # 1st layer weights
weights2 = (np.random.randn(nOutputs, nHiddens) - 0.5)     # 2nd layer weights

# initialize all weights to zeros
# weights1 = np.zeros((nHiddens, nInputs))
# weights2 = np.zeros((nOutputs, nHiddens))

bias1 = (np.random.randn(nHiddens, 1) - 0.5)               # 1st layer biases
bias2 = (np.random.randn(nOutputs, 1) - 0.5)               # 2nd layer biases

# First plot the patterns
fig = plot_patterns(patterns, desired)

#Another common activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Iterate for a fixed number of iterations
for epoch in range(100000):
  
    #Forward propagation
    y1 = sigmoid(np.dot(weights1, inputs) + bias1)
    y2 = sigmoid(np.dot(weights2, y1) + bias2)
    
    
    #Backward propagation
    dw2 = 2 * np.dot((y2 - desired) * y2*(1-y2), y1.T) # y2*(1-y2) correspond to the derivative of the sigmoid function -> phi'(x) = phi(x)(1-phi(x))
    dw1 = 2 * np.dot(np.dot(weights2.T, (y2 - desired)) * y2*(1-y2) * y1*(1-y1), inputs.T)    
    
    db2 = 2 * np.mean((y2 - desired) * y2*(1-y2))
    db1 = 2 * np.mean((y2 - desired) * y2*(1-y2) * y1*(1-y1))
    
    weights1 -= eta * dw1
    weights2 -= eta * dw2
    bias1 -= eta * db1
    bias2 -= eta * db2
    
    TSS = np.sum(np.power(np.abs(y2 - desired), 2))
    
    print('Epoch %3d:  Error = %f' % (epoch, TSS))
    if TSS < TSS_Limit:
        break
    if (epoch - 1 % 20)==0:
        plot_boundary(np.concatenate((bias2, weights2), axis=1), epoch, '--', fig)

plot_boundary(np.concatenate((bias1, weights1), axis=1), epoch, '-', fig)
# Out:
# Epoch   0:  Error = 1.523861
# Epoch   1:  Error = 1.523273
# Epoch   2:  Error = 1.522685
# Epoch   3:  Error = 1.522095
# Epoch   4:  Error = 1.521505
# Epoch   5:  Error = 1.520914
# Epoch   6:  Error = 1.520322
# Epoch   7:  Error = 1.519729
# Epoch   8:  Error = 1.519135
# Epoch   9:  Error = 1.518541
# Epoch  10:  Error = 1.517945
# Epoch  11:  Error = 1.517349
# Epoch  12:  Error = 1.516752
# Epoch  13:  Error = 1.516154
# Epoch  14:  Error = 1.515555
# Epoch  15:  Error = 1.514955
# Epoch  16:  Error = 1.514354
# Epoch  17:  Error = 1.513753
# Epoch  18:  Error = 1.513151
# Epoch  19:  Error = 1.512547
# Epoch  20:  Error = 1.511943
# Epoch  21:  Error = 1.511338
# Epoch  22:  Error = 1.510732
# Epoch  23:  Error = 1.510126
# Epoch  24:  Error = 1.509518
# Epoch  25:  Error = 1.508910
# Epoch  26:  Error = 1.508301
# Epoch  27:  Error = 1.507691
# Epoch  28:  Error = 1.507080
# Epoch  29:  Error = 1.506468
# Epoch  30:  Error = 1.505855
# Epoch  31:  Error = 1.505242
# Epoch  32:  Error = 1.504627
# Epoch  33:  Error = 1.504012
# Epoch  34:  Error = 1.503396
# Epoch  35:  Error = 1.502779
# Epoch  36:  Error = 1.502161
# Epoch  37:  Error = 1.501543
# Epoch  38:  Error = 1.500923
# Epoch  39:  Error = 1.500303
# Epoch  40:  Error = 1.499682
# Epoch  41:  Error = 1.499060
# Epoch  42:  Error = 1.498437
# Epoch  43:  Error = 1.497813
# Epoch  44:  Error = 1.497189
# Epoch  45:  Error = 1.496563
# Epoch  46:  Error = 1.495937
# Epoch  47:  Error = 1.495310
# Epoch  48:  Error = 1.494682
# Epoch  49:  Error = 1.494053
# Epoch  50:  Error = 1.493424
# Epoch  51:  Error = 1.492793
# Epoch  52:  Error = 1.492162
# Epoch  53:  Error = 1.491530
# Epoch  54:  Error = 1.490897
# Epoch  55:  Error = 1.490263
# Epoch  56:  Error = 1.489628
# Epoch  57:  Error = 1.488993
# Epoch  58:  Error = 1.488357
# Epoch  59:  Error = 1.487719
# Epoch  60:  Error = 1.487081
# Epoch  61:  Error = 1.486443
# Epoch  62:  Error = 1.485803
# Epoch  63:  Error = 1.485163
# Epoch  64:  Error = 1.484521
# Epoch  65:  Error = 1.483879
# Epoch  66:  Error = 1.483236
# Epoch  67:  Error = 1.482593
# Epoch  68:  Error = 1.481948
# Epoch  69:  Error = 1.481303
# Epoch  70:  Error = 1.480656
# Epoch  71:  Error = 1.480009
# Epoch  72:  Error = 1.479362
# Epoch  73:  Error = 1.478713
# Epoch  74:  Error = 1.478064
# Epoch  75:  Error = 1.477413
# Epoch  76:  Error = 1.476762
# Epoch  77:  Error = 1.476110
# Epoch  78:  Error = 1.475458
# Epoch  79:  Error = 1.474804
# Epoch  80:  Error = 1.474150
# Epoch  81:  Error = 1.473495
# Epoch  82:  Error = 1.472839
# Epoch  83:  Error = 1.472182
# Epoch  84:  Error = 1.471525
# Epoch  85:  Error = 1.470866
# Epoch  86:  Error = 1.470207
# Epoch  87:  Error = 1.469547
# Epoch  88:  Error = 1.468887
# Epoch  89:  Error = 1.468225
# Epoch  90:  Error = 1.467563
# Epoch  91:  Error = 1.466900
# Epoch  92:  Error = 1.466236
# Epoch  93:  Error = 1.465572
# Epoch  94:  Error = 1.464906
# Epoch  95:  Error = 1.464240
# Epoch  96:  Error = 1.463573
# Epoch  97:  Error = 1.462905
# Epoch  98:  Error = 1.462237
# Epoch  99:  Error = 1.461568
# Epoch 100:  Error = 1.460898
# Epoch 101:  Error = 1.460227
# Epoch 102:  Error = 1.459555
# Epoch 103:  Error = 1.458883
# Epoch 104:  Error = 1.458210
# Epoch 105:  Error = 1.457536
# Epoch 106:  Error = 1.456862
# Epoch 107:  Error = 1.456186
# Epoch 108:  Error = 1.455510
# Epoch 109:  Error = 1.454833
# Epoch 110:  Error = 1.454156
# Epoch 111:  Error = 1.453477
# Epoch 112:  Error = 1.452798
# Epoch 113:  Error = 1.452119
# Epoch 114:  Error = 1.451438
# Epoch 115:  Error = 1.450757
# Epoch 116:  Error = 1.450075
# Epoch 117:  Error = 1.449392
# Epoch 118:  Error = 1.448709
# Epoch 119:  Error = 1.448024
# Epoch 120:  Error = 1.447339
# Epoch 121:  Error = 1.446654
# Epoch 122:  Error = 1.445967
# Epoch 123:  Error = 1.445280
# Epoch 124:  Error = 1.444593
# Epoch 125:  Error = 1.443904
# Epoch 126:  Error = 1.443215
# Epoch 127:  Error = 1.442525
# Epoch 128:  Error = 1.441834
# Epoch 129:  Error = 1.441143
# Epoch 130:  Error = 1.440451
# Epoch 131:  Error = 1.439758
# Epoch 132:  Error = 1.439065
# Epoch 133:  Error = 1.438371
# Epoch 134:  Error = 1.437676
# Epoch 135:  Error = 1.436981
# Epoch 136:  Error = 1.436284
# Epoch 137:  Error = 1.435588
# Epoch 138:  Error = 1.434890
# Epoch 139:  Error = 1.434192
# Epoch 140:  Error = 1.433493
# Epoch 141:  Error = 1.432794
# Epoch 142:  Error = 1.432094
# Epoch 143:  Error = 1.431393
# Epoch 144:  Error = 1.430691
# Epoch 145:  Error = 1.429989
# Epoch 146:  Error = 1.429286
# Epoch 147:  Error = 1.428583
# Epoch 148:  Error = 1.427879
# Epoch 149:  Error = 1.427174
# Epoch 150:  Error = 1.426469
# Epoch 151:  Error = 1.425763
# Epoch 152:  Error = 1.425056
# Epoch 153:  Error = 1.424349
# Epoch 154:  Error = 1.423641
# Epoch 155:  Error = 1.422933
# Epoch 156:  Error = 1.422224
# Epoch 157:  Error = 1.421514
# Epoch 158:  Error = 1.420804
# Epoch 159:  Error = 1.420093
# Epoch 160:  Error = 1.419381
# Epoch 161:  Error = 1.418669
# Epoch 162:  Error = 1.417956
# Epoch 163:  Error = 1.417243
# Epoch 164:  Error = 1.416529
# Epoch 165:  Error = 1.415815
# Epoch 166:  Error = 1.415100
# Epoch 167:  Error = 1.414384
# Epoch 168:  Error = 1.413668
# Epoch 169:  Error = 1.412951
# Epoch 170:  Error = 1.412234
# Epoch 171:  Error = 1.411516
# Epoch 172:  Error = 1.410797
# Epoch 173:  Error = 1.410078
# Epoch 174:  Error = 1.409359
# Epoch 175:  Error = 1.408639
# Epoch 176:  Error = 1.407918
# Epoch 177:  Error = 1.407197
# Epoch 178:  Error = 1.406475
# Epoch 179:  Error = 1.405753
# Epoch 180:  Error = 1.405030
# Epoch 181:  Error = 1.404307
# Epoch 182:  Error = 1.403583
# Epoch 183:  Error = 1.402858
# Epoch 184:  Error = 1.402134
# Epoch 185:  Error = 1.401408
# Epoch 186:  Error = 1.400682
# Epoch 187:  Error = 1.399956
# Epoch 188:  Error = 1.399229
# Epoch 189:  Error = 1.398502
# Epoch 190:  Error = 1.397774
# Epoch 191:  Error = 1.397046
# Epoch 192:  Error = 1.396317
# Epoch 193:  Error = 1.395588
# Epoch 194:  Error = 1.394858
# Epoch 195:  Error = 1.394128
# Epoch 196:  Error = 1.393397
# Epoch 197:  Error = 1.392666
# Epoch 198:  Error = 1.391935
# Epoch 199:  Error = 1.391203
# Epoch 200:  Error = 1.390470
# Epoch 201:  Error = 1.389737
# Epoch 202:  Error = 1.389004
# Epoch 203:  Error = 1.388270
# Epoch 204:  Error = 1.387536
# Epoch 205:  Error = 1.386802
# Epoch 206:  Error = 1.386067
# Epoch 207:  Error = 1.385331
# Epoch 208:  Error = 1.384596
# Epoch 209:  Error = 1.383859
# Epoch 210:  Error = 1.383123
# Epoch 211:  Error = 1.382386
# Epoch 212:  Error = 1.381649
# Epoch 213:  Error = 1.380911
# Epoch 214:  Error = 1.380173
# Epoch 215:  Error = 1.379435
# Epoch 216:  Error = 1.378696
# Epoch 217:  Error = 1.377957
# Epoch 218:  Error = 1.377217
# Epoch 219:  Error = 1.376477
# Epoch 220:  Error = 1.375737
# Epoch 221:  Error = 1.374997
# Epoch 222:  Error = 1.374256
# Epoch 223:  Error = 1.373515
# Epoch 224:  Error = 1.372773
# Epoch 225:  Error = 1.372031
# Epoch 226:  Error = 1.371289
# Epoch 227:  Error = 1.370547
# Epoch 228:  Error = 1.369804
# Epoch 229:  Error = 1.369061
# Epoch 230:  Error = 1.368318
# Epoch 231:  Error = 1.367574
# Epoch 232:  Error = 1.366830
# Epoch 233:  Error = 1.366086
# Epoch 234:  Error = 1.365342
# Epoch 235:  Error = 1.364597
# Epoch 236:  Error = 1.363852
# Epoch 237:  Error = 1.363107
# Epoch 238:  Error = 1.362362
# Epoch 239:  Error = 1.361616
# Epoch 240:  Error = 1.360870
# Epoch 241:  Error = 1.360124
# Epoch 242:  Error = 1.359378
# Epoch 243:  Error = 1.358631
# Epoch 244:  Error = 1.357885
# Epoch 245:  Error = 1.357138
# Epoch 246:  Error = 1.356390
# Epoch 247:  Error = 1.355643
# Epoch 248:  Error = 1.354896
# Epoch 249:  Error = 1.354148
# Epoch 250:  Error = 1.353400
# Epoch 251:  Error = 1.352652
# Epoch 252:  Error = 1.351904
# Epoch 253:  Error = 1.351155
# Epoch 254:  Error = 1.350407
# Epoch 255:  Error = 1.349658
# Epoch 256:  Error = 1.348909
# Epoch 257:  Error = 1.348160
# Epoch 258:  Error = 1.347411
# Epoch 259:  Error = 1.346662
# Epoch 260:  Error = 1.345913
# Epoch 261:  Error = 1.345163
# Epoch 262:  Error = 1.344414
# Epoch 263:  Error = 1.343664
# Epoch 264:  Error = 1.342915
# Epoch 265:  Error = 1.342165
# Epoch 266:  Error = 1.341415
# Epoch 267:  Error = 1.340665
# Epoch 268:  Error = 1.339915
# Epoch 269:  Error = 1.339165
# Epoch 270:  Error = 1.338415
# Epoch 271:  Error = 1.337665
# Epoch 272:  Error = 1.336914
# Epoch 273:  Error = 1.336164
# Epoch 274:  Error = 1.335414
# Epoch 275:  Error = 1.334664
# Epoch 276:  Error = 1.333913
# Epoch 277:  Error = 1.333163
# Epoch 278:  Error = 1.332413
# Epoch 279:  Error = 1.331662
# Epoch 280:  Error = 1.330912
# Epoch 281:  Error = 1.330162
# Epoch 282:  Error = 1.329412
# Epoch 283:  Error = 1.328661
# Epoch 284:  Error = 1.327911
# Epoch 285:  Error = 1.327161
# Epoch 286:  Error = 1.326411
# Epoch 287:  Error = 1.325661
# Epoch 288:  Error = 1.324911
# Epoch 289:  Error = 1.324161
# Epoch 290:  Error = 1.323411
# Epoch 291:  Error = 1.322661
# Epoch 292:  Error = 1.321912
# Epoch 293:  Error = 1.321162
# Epoch 294:  Error = 1.320413
# Epoch 295:  Error = 1.319663
# Epoch 296:  Error = 1.318914
# Epoch 297:  Error = 1.318165
# Epoch 298:  Error = 1.317416
# Epoch 299:  Error = 1.316667
# Epoch 300:  Error = 1.315918
# Epoch 301:  Error = 1.315170
# Epoch 302:  Error = 1.314421
# Epoch 303:  Error = 1.313673
# Epoch 304:  Error = 1.312925
# Epoch 305:  Error = 1.312177
# Epoch 306:  Error = 1.311429
# Epoch 307:  Error = 1.310681
# Epoch 308:  Error = 1.309934
# Epoch 309:  Error = 1.309187
# Epoch 310:  Error = 1.308440
# Epoch 311:  Error = 1.307693
# Epoch 312:  Error = 1.306947
# Epoch 313:  Error = 1.306200
# Epoch 314:  Error = 1.305454
# Epoch 315:  Error = 1.304709
# Epoch 316:  Error = 1.303963
# Epoch 317:  Error = 1.303218
# Epoch 318:  Error = 1.302473
# Epoch 319:  Error = 1.301728
# Epoch 320:  Error = 1.300983
# Epoch 321:  Error = 1.300239
# Epoch 322:  Error = 1.299495
# Epoch 323:  Error = 1.298752
# Epoch 324:  Error = 1.298008
# Epoch 325:  Error = 1.297265
# Epoch 326:  Error = 1.296523
# Epoch 327:  Error = 1.295780
# Epoch 328:  Error = 1.295038
# Epoch 329:  Error = 1.294296
# Epoch 330:  Error = 1.293555
# Epoch 331:  Error = 1.292814
# Epoch 332:  Error = 1.292073
# Epoch 333:  Error = 1.291333
# Epoch 334:  Error = 1.290593
# Epoch 335:  Error = 1.289854
# Epoch 336:  Error = 1.289114
# Epoch 337:  Error = 1.288376
# Epoch 338:  Error = 1.287637
# Epoch 339:  Error = 1.286899
# Epoch 340:  Error = 1.286162
# Epoch 341:  Error = 1.285425
# Epoch 342:  Error = 1.284688
# Epoch 343:  Error = 1.283952
# Epoch 344:  Error = 1.283216
# Epoch 345:  Error = 1.282481
# Epoch 346:  Error = 1.281746
# Epoch 347:  Error = 1.281011
# Epoch 348:  Error = 1.280277
# Epoch 349:  Error = 1.279544
# Epoch 350:  Error = 1.278811
# Epoch 351:  Error = 1.278078
# Epoch 352:  Error = 1.277346
# Epoch 353:  Error = 1.276614
# Epoch 354:  Error = 1.275883
# Epoch 355:  Error = 1.275153
# Epoch 356:  Error = 1.274423
# Epoch 357:  Error = 1.273693
# Epoch 358:  Error = 1.272965
# Epoch 359:  Error = 1.272236
# Epoch 360:  Error = 1.271508
# Epoch 361:  Error = 1.270781
# Epoch 362:  Error = 1.270054
# Epoch 363:  Error = 1.269328
# Epoch 364:  Error = 1.268603
# Epoch 365:  Error = 1.267878
# Epoch 366:  Error = 1.267153
# Epoch 367:  Error = 1.266429
# Epoch 368:  Error = 1.265706
# Epoch 369:  Error = 1.264984
# Epoch 370:  Error = 1.264262
# Epoch 371:  Error = 1.263540
# Epoch 372:  Error = 1.262819
# Epoch 373:  Error = 1.262099
# Epoch 374:  Error = 1.261380
# Epoch 375:  Error = 1.260661
# Epoch 376:  Error = 1.259943
# Epoch 377:  Error = 1.259225
# Epoch 378:  Error = 1.258509
# Epoch 379:  Error = 1.257793
# Epoch 380:  Error = 1.257077
# Epoch 381:  Error = 1.256362
# Epoch 382:  Error = 1.255648
# Epoch 383:  Error = 1.254935
# Epoch 384:  Error = 1.254222
# Epoch 385:  Error = 1.253510
# Epoch 386:  Error = 1.252799
# Epoch 387:  Error = 1.252089
# Epoch 388:  Error = 1.251379
# Epoch 389:  Error = 1.250670
# Epoch 390:  Error = 1.249961
# Epoch 391:  Error = 1.249254
# Epoch 392:  Error = 1.248547
# Epoch 393:  Error = 1.247841
# Epoch 394:  Error = 1.247136
# Epoch 395:  Error = 1.246431
# Epoch 396:  Error = 1.245728
# Epoch 397:  Error = 1.245025
# Epoch 398:  Error = 1.244323
# Epoch 399:  Error = 1.243622
# Epoch 400:  Error = 1.242921
# Epoch 401:  Error = 1.242221
# Epoch 402:  Error = 1.241523
# Epoch 403:  Error = 1.240825
# Epoch 404:  Error = 1.240127
# Epoch 405:  Error = 1.239431
# Epoch 406:  Error = 1.238736
# Epoch 407:  Error = 1.238041
# Epoch 408:  Error = 1.237347
# Epoch 409:  Error = 1.236654
# Epoch 410:  Error = 1.235962
# Epoch 411:  Error = 1.235271
# Epoch 412:  Error = 1.234581
# Epoch 413:  Error = 1.233891
# Epoch 414:  Error = 1.233203
# Epoch 415:  Error = 1.232515
# Epoch 416:  Error = 1.231828
# Epoch 417:  Error = 1.231143
# Epoch 418:  Error = 1.230458
# Epoch 419:  Error = 1.229774
# Epoch 420:  Error = 1.229091
# Epoch 421:  Error = 1.228409
# Epoch 422:  Error = 1.227728
# Epoch 423:  Error = 1.227047
# Epoch 424:  Error = 1.226368
# Epoch 425:  Error = 1.225690
# Epoch 426:  Error = 1.225012
# Epoch 427:  Error = 1.224336
# Epoch 428:  Error = 1.223661
# Epoch 429:  Error = 1.222986
# Epoch 430:  Error = 1.222313
# Epoch 431:  Error = 1.221640
# Epoch 432:  Error = 1.220969
# Epoch 433:  Error = 1.220298
# Epoch 434:  Error = 1.219629
# Epoch 435:  Error = 1.218960
# Epoch 436:  Error = 1.218293
# Epoch 437:  Error = 1.217626
# Epoch 438:  Error = 1.216961
# Epoch 439:  Error = 1.216297
# Epoch 440:  Error = 1.215633
# Epoch 441:  Error = 1.214971
# Epoch 442:  Error = 1.214310
# Epoch 443:  Error = 1.213649
# Epoch 444:  Error = 1.212990
# Epoch 445:  Error = 1.212332
# Epoch 446:  Error = 1.211675
# Epoch 447:  Error = 1.211019
# Epoch 448:  Error = 1.210364
# Epoch 449:  Error = 1.209710
# Epoch 450:  Error = 1.209058
# Epoch 451:  Error = 1.208406
# Epoch 452:  Error = 1.207756
# Epoch 453:  Error = 1.207106
# Epoch 454:  Error = 1.206458
# Epoch 455:  Error = 1.205811
# Epoch 456:  Error = 1.205164
# Epoch 457:  Error = 1.204519
# Epoch 458:  Error = 1.203876
# Epoch 459:  Error = 1.203233
# Epoch 460:  Error = 1.202591
# Epoch 461:  Error = 1.201951
# Epoch 462:  Error = 1.201311
# Epoch 463:  Error = 1.200673
# Epoch 464:  Error = 1.200036
# Epoch 465:  Error = 1.199400
# Epoch 466:  Error = 1.198765
# Epoch 467:  Error = 1.198132
# Epoch 468:  Error = 1.197499
# Epoch 469:  Error = 1.196868
# Epoch 470:  Error = 1.196238
# Epoch 471:  Error = 1.195609
# Epoch 472:  Error = 1.194981
# Epoch 473:  Error = 1.194355
# Epoch 474:  Error = 1.193729
# Epoch 475:  Error = 1.193105
# Epoch 476:  Error = 1.192482
# Epoch 477:  Error = 1.191860
# Epoch 478:  Error = 1.191240
# Epoch 479:  Error = 1.190620
# Epoch 480:  Error = 1.190002
# Epoch 481:  Error = 1.189385
# Epoch 482:  Error = 1.188769
# Epoch 483:  Error = 1.188155
# Epoch 484:  Error = 1.187542
# Epoch 485:  Error = 1.186930
# Epoch 486:  Error = 1.186319
# Epoch 487:  Error = 1.185709
# Epoch 488:  Error = 1.185101
# Epoch 489:  Error = 1.184494
# Epoch 490:  Error = 1.183888
# Epoch 491:  Error = 1.183283
# Epoch 492:  Error = 1.182680
# Epoch 493:  Error = 1.182078
# Epoch 494:  Error = 1.181477
# Epoch 495:  Error = 1.180877
# Epoch 496:  Error = 1.180279
# Epoch 497:  Error = 1.179682
# Epoch 498:  Error = 1.179086
# Epoch 499:  Error = 1.178491
# Epoch 500:  Error = 1.177898
# Epoch 501:  Error = 1.177306
# Epoch 502:  Error = 1.176716
# Epoch 503:  Error = 1.176126
# Epoch 504:  Error = 1.175538
# Epoch 505:  Error = 1.174951
# Epoch 506:  Error = 1.174366
# Epoch 507:  Error = 1.173781
# Epoch 508:  Error = 1.173198
# Epoch 509:  Error = 1.172617
# Epoch 510:  Error = 1.172036
# Epoch 511:  Error = 1.171457
# Epoch 512:  Error = 1.170880
# Epoch 513:  Error = 1.170303
# Epoch 514:  Error = 1.169728
# Epoch 515:  Error = 1.169154
# Epoch 516:  Error = 1.168582
# Epoch 517:  Error = 1.168011
# Epoch 518:  Error = 1.167441
# Epoch 519:  Error = 1.166872
# Epoch 520:  Error = 1.166305
# Epoch 521:  Error = 1.165739
# Epoch 522:  Error = 1.165175
# Epoch 523:  Error = 1.164612
# Epoch 524:  Error = 1.164050
# Epoch 525:  Error = 1.163489
# Epoch 526:  Error = 1.162930
# Epoch 527:  Error = 1.162372
# Epoch 528:  Error = 1.161816
# Epoch 529:  Error = 1.161261
# Epoch 530:  Error = 1.160707
# Epoch 531:  Error = 1.160154
# Epoch 532:  Error = 1.159603
# Epoch 533:  Error = 1.159054
# Epoch 534:  Error = 1.158505
# Epoch 535:  Error = 1.157958
# Epoch 536:  Error = 1.157412
# Epoch 537:  Error = 1.156868
# Epoch 538:  Error = 1.156325
# Epoch 539:  Error = 1.155783
# Epoch 540:  Error = 1.155243
# Epoch 541:  Error = 1.154704
# Epoch 542:  Error = 1.154167
# Epoch 543:  Error = 1.153631
# Epoch 544:  Error = 1.153096
# Epoch 545:  Error = 1.152562
# Epoch 546:  Error = 1.152030
# Epoch 547:  Error = 1.151500
# Epoch 548:  Error = 1.150970
# Epoch 549:  Error = 1.150442
# Epoch 550:  Error = 1.149916
# Epoch 551:  Error = 1.149390
# Epoch 552:  Error = 1.148867
# Epoch 553:  Error = 1.148344
# Epoch 554:  Error = 1.147823
# Epoch 555:  Error = 1.147303
# Epoch 556:  Error = 1.146785
# Epoch 557:  Error = 1.146268
# Epoch 558:  Error = 1.145752
# Epoch 559:  Error = 1.145238
# Epoch 560:  Error = 1.144725
# Epoch 561:  Error = 1.144214
# Epoch 562:  Error = 1.143704
# Epoch 563:  Error = 1.143195
# Epoch 564:  Error = 1.142688
# Epoch 565:  Error = 1.142182
# Epoch 566:  Error = 1.141677
# Epoch 567:  Error = 1.141174
# Epoch 568:  Error = 1.140672
# Epoch 569:  Error = 1.140172
# Epoch 570:  Error = 1.139673
# Epoch 571:  Error = 1.139175
# Epoch 572:  Error = 1.138679
# Epoch 573:  Error = 1.138184
# Epoch 574:  Error = 1.137691
# Epoch 575:  Error = 1.137199
# Epoch 576:  Error = 1.136708
# Epoch 577:  Error = 1.136219
# Epoch 578:  Error = 1.135731
# Epoch 579:  Error = 1.135244
# Epoch 580:  Error = 1.134759
# Epoch 581:  Error = 1.134275
# Epoch 582:  Error = 1.133793
# Epoch 583:  Error = 1.133312
# Epoch 584:  Error = 1.132832
# Epoch 585:  Error = 1.132354
# Epoch 586:  Error = 1.131877
# Epoch 587:  Error = 1.131402
# Epoch 588:  Error = 1.130928
# Epoch 589:  Error = 1.130455
# Epoch 590:  Error = 1.129984
# Epoch 591:  Error = 1.129514
# Epoch 592:  Error = 1.129045
# Epoch 593:  Error = 1.128578
# Epoch 594:  Error = 1.128112
# Epoch 595:  Error = 1.127648
# Epoch 596:  Error = 1.127185
# Epoch 597:  Error = 1.126723
# Epoch 598:  Error = 1.126263
# Epoch 599:  Error = 1.125804
# Epoch 600:  Error = 1.125347
# Epoch 601:  Error = 1.124890
# Epoch 602:  Error = 1.124436
# Epoch 603:  Error = 1.123982
# Epoch 604:  Error = 1.123530
# Epoch 605:  Error = 1.123080
# Epoch 606:  Error = 1.122630
# Epoch 607:  Error = 1.122182
# Epoch 608:  Error = 1.121736
# Epoch 609:  Error = 1.121291
# Epoch 610:  Error = 1.120847
# Epoch 611:  Error = 1.120405
# Epoch 612:  Error = 1.119963
# Epoch 613:  Error = 1.119524
# Epoch 614:  Error = 1.119085
# Epoch 615:  Error = 1.118648
# Epoch 616:  Error = 1.118213
# Epoch 617:  Error = 1.117779
# Epoch 618:  Error = 1.117346
# Epoch 619:  Error = 1.116914
# Epoch 620:  Error = 1.116484
# Epoch 621:  Error = 1.116055
# Epoch 622:  Error = 1.115628
# Epoch 623:  Error = 1.115202
# Epoch 624:  Error = 1.114777
# Epoch 625:  Error = 1.114353
# Epoch 626:  Error = 1.113931
# Epoch 627:  Error = 1.113511
# Epoch 628:  Error = 1.113091
# Epoch 629:  Error = 1.112673
# Epoch 630:  Error = 1.112257
# Epoch 631:  Error = 1.111841
# Epoch 632:  Error = 1.111427
# Epoch 633:  Error = 1.111014
# Epoch 634:  Error = 1.110603
# Epoch 635:  Error = 1.110193
# Epoch 636:  Error = 1.109784
# Epoch 637:  Error = 1.109377
# Epoch 638:  Error = 1.108971
# Epoch 639:  Error = 1.108566
# Epoch 640:  Error = 1.108163
# Epoch 641:  Error = 1.107761
# Epoch 642:  Error = 1.107360
# Epoch 643:  Error = 1.106961
# Epoch 644:  Error = 1.106563
# Epoch 645:  Error = 1.106166
# Epoch 646:  Error = 1.105771
# Epoch 647:  Error = 1.105377
# Epoch 648:  Error = 1.104984
# Epoch 649:  Error = 1.104592
# Epoch 650:  Error = 1.104202
# Epoch 651:  Error = 1.103813
# Epoch 652:  Error = 1.103426
# Epoch 653:  Error = 1.103039
# Epoch 654:  Error = 1.102654
# Epoch 655:  Error = 1.102271
# Epoch 656:  Error = 1.101888
# Epoch 657:  Error = 1.101507
# Epoch 658:  Error = 1.101127
# Epoch 659:  Error = 1.100749
# Epoch 660:  Error = 1.100372
# Epoch 661:  Error = 1.099996
# Epoch 662:  Error = 1.099621
# Epoch 663:  Error = 1.099248
# Epoch 664:  Error = 1.098876
# Epoch 665:  Error = 1.098505
# Epoch 666:  Error = 1.098135
# Epoch 667:  Error = 1.097767
# Epoch 668:  Error = 1.097400
# Epoch 669:  Error = 1.097034
# Epoch 670:  Error = 1.096670
# Epoch 671:  Error = 1.096307
# Epoch 672:  Error = 1.095945
# Epoch 673:  Error = 1.095584
# Epoch 674:  Error = 1.095225
# Epoch 675:  Error = 1.094866
# Epoch 676:  Error = 1.094509
# Epoch 677:  Error = 1.094154
# Epoch 678:  Error = 1.093799
# Epoch 679:  Error = 1.093446
# Epoch 680:  Error = 1.093094
# Epoch 681:  Error = 1.092743
# Epoch 682:  Error = 1.092394
# Epoch 683:  Error = 1.092046
# Epoch 684:  Error = 1.091699
# Epoch 685:  Error = 1.091353
# Epoch 686:  Error = 1.091008
# Epoch 687:  Error = 1.090665
# Epoch 688:  Error = 1.090323
# Epoch 689:  Error = 1.089982
# Epoch 690:  Error = 1.089642
# Epoch 691:  Error = 1.089304
# Epoch 692:  Error = 1.088967
# Epoch 693:  Error = 1.088631
# Epoch 694:  Error = 1.088296
# Epoch 695:  Error = 1.087962
# Epoch 696:  Error = 1.087630
# Epoch 697:  Error = 1.087298
# Epoch 698:  Error = 1.086968
# Epoch 699:  Error = 1.086639
# Epoch 700:  Error = 1.086312
# Epoch 701:  Error = 1.085985
# Epoch 702:  Error = 1.085660
# Epoch 703:  Error = 1.085336
# Epoch 704:  Error = 1.085013
# Epoch 705:  Error = 1.084691
# Epoch 706:  Error = 1.084371
# Epoch 707:  Error = 1.084051
# Epoch 708:  Error = 1.083733
# Epoch 709:  Error = 1.083416
# Epoch 710:  Error = 1.083100
# Epoch 711:  Error = 1.082785
# Epoch 712:  Error = 1.082472
# Epoch 713:  Error = 1.082159
# Epoch 714:  Error = 1.081848
# Epoch 715:  Error = 1.081538
# Epoch 716:  Error = 1.081229
# Epoch 717:  Error = 1.080921
# Epoch 718:  Error = 1.080614
# Epoch 719:  Error = 1.080308
# Epoch 720:  Error = 1.080004
# Epoch 721:  Error = 1.079701
# Epoch 722:  Error = 1.079398
# Epoch 723:  Error = 1.079097
# Epoch 724:  Error = 1.078797
# Epoch 725:  Error = 1.078499
# Epoch 726:  Error = 1.078201
# Epoch 727:  Error = 1.077904
# Epoch 728:  Error = 1.077609
# Epoch 729:  Error = 1.077314
# Epoch 730:  Error = 1.077021
# Epoch 731:  Error = 1.076729
# Epoch 732:  Error = 1.076438
# Epoch 733:  Error = 1.076148
# Epoch 734:  Error = 1.075859
# Epoch 735:  Error = 1.075571
# Epoch 736:  Error = 1.075284
# Epoch 737:  Error = 1.074999
# Epoch 738:  Error = 1.074714
# Epoch 739:  Error = 1.074431
# Epoch 740:  Error = 1.074148
# Epoch 741:  Error = 1.073867
# Epoch 742:  Error = 1.073587
# Epoch 743:  Error = 1.073308
# Epoch 744:  Error = 1.073029
# Epoch 745:  Error = 1.072752
# Epoch 746:  Error = 1.072476
# Epoch 747:  Error = 1.072201
# Epoch 748:  Error = 1.071927
# Epoch 749:  Error = 1.071655
# Epoch 750:  Error = 1.071383
# Epoch 751:  Error = 1.071112
# Epoch 752:  Error = 1.070842
# Epoch 753:  Error = 1.070574
# Epoch 754:  Error = 1.070306
# Epoch 755:  Error = 1.070039
# Epoch 756:  Error = 1.069774
# Epoch 757:  Error = 1.069509
# Epoch 758:  Error = 1.069246
# Epoch 759:  Error = 1.068983
# Epoch 760:  Error = 1.068722
# Epoch 761:  Error = 1.068461
# Epoch 762:  Error = 1.068201
# Epoch 763:  Error = 1.067943
# Epoch 764:  Error = 1.067686
# Epoch 765:  Error = 1.067429
# Epoch 766:  Error = 1.067174
# Epoch 767:  Error = 1.066919
# Epoch 768:  Error = 1.066665
# Epoch 769:  Error = 1.066413
# Epoch 770:  Error = 1.066161
# Epoch 771:  Error = 1.065911
# Epoch 772:  Error = 1.065661
# Epoch 773:  Error = 1.065413
# Epoch 774:  Error = 1.065165
# Epoch 775:  Error = 1.064918
# Epoch 776:  Error = 1.064673
# Epoch 777:  Error = 1.064428
# Epoch 778:  Error = 1.064184
# Epoch 779:  Error = 1.063941
# Epoch 780:  Error = 1.063700
# Epoch 781:  Error = 1.063459
# Epoch 782:  Error = 1.063219
# Epoch 783:  Error = 1.062980
# Epoch 784:  Error = 1.062742
# Epoch 785:  Error = 1.062504
# Epoch 786:  Error = 1.062268
# Epoch 787:  Error = 1.062033
# Epoch 788:  Error = 1.061799
# Epoch 789:  Error = 1.061565
# Epoch 790:  Error = 1.061333
# Epoch 791:  Error = 1.061101
# Epoch 792:  Error = 1.060871
# Epoch 793:  Error = 1.060641
# Epoch 794:  Error = 1.060412
# Epoch 795:  Error = 1.060184
# Epoch 796:  Error = 1.059957
# Epoch 797:  Error = 1.059731
# Epoch 798:  Error = 1.059506
# Epoch 799:  Error = 1.059282
# Epoch 800:  Error = 1.059058
# Epoch 801:  Error = 1.058836
# Epoch 802:  Error = 1.058614
# Epoch 803:  Error = 1.058393
# Epoch 804:  Error = 1.058173
# Epoch 805:  Error = 1.057954
# Epoch 806:  Error = 1.057736
# Epoch 807:  Error = 1.057519
# Epoch 808:  Error = 1.057303
# Epoch 809:  Error = 1.057087
# Epoch 810:  Error = 1.056873
# Epoch 811:  Error = 1.056659
# Epoch 812:  Error = 1.056446
# Epoch 813:  Error = 1.056234
# Epoch 814:  Error = 1.056023
# Epoch 815:  Error = 1.055812
# Epoch 816:  Error = 1.055603
# Epoch 817:  Error = 1.055394
# Epoch 818:  Error = 1.055187
# Epoch 819:  Error = 1.054980
# Epoch 820:  Error = 1.054773
# Epoch 821:  Error = 1.054568
# Epoch 822:  Error = 1.054364
# Epoch 823:  Error = 1.054160
# Epoch 824:  Error = 1.053957
# Epoch 825:  Error = 1.053755
# Epoch 826:  Error = 1.053554
# Epoch 827:  Error = 1.053354
# Epoch 828:  Error = 1.053154
# Epoch 829:  Error = 1.052955
# Epoch 830:  Error = 1.052757
# Epoch 831:  Error = 1.052560
# Epoch 832:  Error = 1.052364
# Epoch 833:  Error = 1.052168
# Epoch 834:  Error = 1.051974
# Epoch 835:  Error = 1.051780
# Epoch 836:  Error = 1.051586
# Epoch 837:  Error = 1.051394
# Epoch 838:  Error = 1.051203
# Epoch 839:  Error = 1.051012
# Epoch 840:  Error = 1.050822
# Epoch 841:  Error = 1.050632
# Epoch 842:  Error = 1.050444
# Epoch 843:  Error = 1.050256
# Epoch 844:  Error = 1.050069
# Epoch 845:  Error = 1.049883
# Epoch 846:  Error = 1.049698
# Epoch 847:  Error = 1.049513
# Epoch 848:  Error = 1.049329
# Epoch 849:  Error = 1.049146
# Epoch 850:  Error = 1.048963
# Epoch 851:  Error = 1.048782
# Epoch 852:  Error = 1.048601
# Epoch 853:  Error = 1.048421
# Epoch 854:  Error = 1.048241
# Epoch 855:  Error = 1.048062
# Epoch 856:  Error = 1.047885
# Epoch 857:  Error = 1.047707
# Epoch 858:  Error = 1.047531
# Epoch 859:  Error = 1.047355
# Epoch 860:  Error = 1.047180
# Epoch 861:  Error = 1.047006
# Epoch 862:  Error = 1.046832
# Epoch 863:  Error = 1.046659
# Epoch 864:  Error = 1.046487
# Epoch 865:  Error = 1.046315
# Epoch 866:  Error = 1.046144
# Epoch 867:  Error = 1.045974
# Epoch 868:  Error = 1.045805
# Epoch 869:  Error = 1.045636
# Epoch 870:  Error = 1.045468
# Epoch 871:  Error = 1.045301
# Epoch 872:  Error = 1.045134
# Epoch 873:  Error = 1.044968
# Epoch 874:  Error = 1.044803
# Epoch 875:  Error = 1.044639
# Epoch 876:  Error = 1.044475
# Epoch 877:  Error = 1.044312
# Epoch 878:  Error = 1.044149
# Epoch 879:  Error = 1.043987
# Epoch 880:  Error = 1.043826
# Epoch 881:  Error = 1.043665
# Epoch 882:  Error = 1.043506
# Epoch 883:  Error = 1.043346
# Epoch 884:  Error = 1.043188
# Epoch 885:  Error = 1.043030
# Epoch 886:  Error = 1.042873
# Epoch 887:  Error = 1.042716
# Epoch 888:  Error = 1.042560
# Epoch 889:  Error = 1.042405
# Epoch 890:  Error = 1.042250
# Epoch 891:  Error = 1.042096
# Epoch 892:  Error = 1.041943
# Epoch 893:  Error = 1.041790
# Epoch 894:  Error = 1.041638
# Epoch 895:  Error = 1.041487
# Epoch 896:  Error = 1.041336
# Epoch 897:  Error = 1.041186
# Epoch 898:  Error = 1.041036
# Epoch 899:  Error = 1.040887
# Epoch 900:  Error = 1.040739
# Epoch 901:  Error = 1.040591
# Epoch 902:  Error = 1.040444
# Epoch 903:  Error = 1.040297
# Epoch 904:  Error = 1.040151
# Epoch 905:  Error = 1.040006
# Epoch 906:  Error = 1.039862
# Epoch 907:  Error = 1.039717
# Epoch 908:  Error = 1.039574
# Epoch 909:  Error = 1.039431
# Epoch 910:  Error = 1.039289
# Epoch 911:  Error = 1.039147
# Epoch 912:  Error = 1.039006
# Epoch 913:  Error = 1.038865
# Epoch 914:  Error = 1.038725
# Epoch 915:  Error = 1.038586
# Epoch 916:  Error = 1.038447
# Epoch 917:  Error = 1.038309
# Epoch 918:  Error = 1.038172
# Epoch 919:  Error = 1.038034
# Epoch 920:  Error = 1.037898
# Epoch 921:  Error = 1.037762
# Epoch 922:  Error = 1.037627
# Epoch 923:  Error = 1.037492
# Epoch 924:  Error = 1.037358
# Epoch 925:  Error = 1.037224
# Epoch 926:  Error = 1.037091
# Epoch 927:  Error = 1.036958
# Epoch 928:  Error = 1.036826
# Epoch 929:  Error = 1.036695
# Epoch 930:  Error = 1.036564
# Epoch 931:  Error = 1.036434
# Epoch 932:  Error = 1.036304
# Epoch 933:  Error = 1.036175
# Epoch 934:  Error = 1.036046
# Epoch 935:  Error = 1.035918
# Epoch 936:  Error = 1.035790
# Epoch 937:  Error = 1.035663
# Epoch 938:  Error = 1.035536
# Epoch 939:  Error = 1.035410
# Epoch 940:  Error = 1.035285
# Epoch 941:  Error = 1.035160
# Epoch 942:  Error = 1.035035
# Epoch 943:  Error = 1.034911
# Epoch 944:  Error = 1.034788
# Epoch 945:  Error = 1.034665
# Epoch 946:  Error = 1.034542
# Epoch 947:  Error = 1.034421
# Epoch 948:  Error = 1.034299
# Epoch 949:  Error = 1.034178
# Epoch 950:  Error = 1.034058
# Epoch 951:  Error = 1.033938
# Epoch 952:  Error = 1.033818
# Epoch 953:  Error = 1.033700
# Epoch 954:  Error = 1.033581
# Epoch 955:  Error = 1.033463
# Epoch 956:  Error = 1.033346
# Epoch 957:  Error = 1.033229
# Epoch 958:  Error = 1.033112
# Epoch 959:  Error = 1.032997
# Epoch 960:  Error = 1.032881
# Epoch 961:  Error = 1.032766
# Epoch 962:  Error = 1.032652
# Epoch 963:  Error = 1.032538
# Epoch 964:  Error = 1.032424
# Epoch 965:  Error = 1.032311
# Epoch 966:  Error = 1.032198
# Epoch 967:  Error = 1.032086
# Epoch 968:  Error = 1.031974
# Epoch 969:  Error = 1.031863
# Epoch 970:  Error = 1.031752
# Epoch 9208:  Error = 0.430527
# Epoch 9209:  Error = 0.430443
# Epoch 9210:  Error = 0.430359
# Epoch 9211:  Error = 0.430275
# Epoch 9212:  Error = 0.430191
# Epoch 9213:  Error = 0.430107
# Epoch 9214:  Error = 0.430023
# Epoch 9215:  Error = 0.429939
# Epoch 9216:  Error = 0.429855
# Epoch 9217:  Error = 0.429771
# Epoch 9218:  Error = 0.429687
# Epoch 9219:  Error = 0.429603
# Epoch 9220:  Error = 0.429519
# Epoch 9221:  Error = 0.429435
# Epoch 9222:  Error = 0.429351
# Epoch 9223:  Error = 0.429268
# Epoch 9224:  Error = 0.429184
# Epoch 9225:  Error = 0.429100
# Epoch 9226:  Error = 0.429016
# Epoch 9227:  Error = 0.428933
# Epoch 9228:  Error = 0.428849
# Epoch 9229:  Error = 0.428765
# Epoch 9230:  Error = 0.428681
# Epoch 9231:  Error = 0.428598
# Epoch 9232:  Error = 0.428514
# Epoch 9233:  Error = 0.428431
# Epoch 9234:  Error = 0.428347
# Epoch 9235:  Error = 0.428263
# Epoch 9236:  Error = 0.428180
# Epoch 9237:  Error = 0.428096
# Epoch 9238:  Error = 0.428013
# Epoch 9239:  Error = 0.427929
# Epoch 9240:  Error = 0.427846
# Epoch 9241:  Error = 0.427762
# Epoch 9242:  Error = 0.427679
# Epoch 9243:  Error = 0.427596
# Epoch 9244:  Error = 0.427512
# Epoch 9245:  Error = 0.427429
# Epoch 9246:  Error = 0.427346
# Epoch 9247:  Error = 0.427262
# Epoch 9248:  Error = 0.427179
# Epoch 9249:  Error = 0.427096
# Epoch 9250:  Error = 0.427012
# Epoch 9251:  Error = 0.426929
# Epoch 9252:  Error = 0.426846
# Epoch 9253:  Error = 0.426763
# Epoch 9254:  Error = 0.426679
# Epoch 9255:  Error = 0.426596
# Epoch 9256:  Error = 0.426513
# Epoch 9257:  Error = 0.426430
# Epoch 9258:  Error = 0.426347
# Epoch 9259:  Error = 0.426264
# Epoch 9260:  Error = 0.426181
# Epoch 9261:  Error = 0.426098
# Epoch 9262:  Error = 0.426015
# Epoch 9263:  Error = 0.425932
# Epoch 9264:  Error = 0.425849
# Epoch 9265:  Error = 0.425766
# Epoch 9266:  Error = 0.425683
# Epoch 9267:  Error = 0.425600
# Epoch 9268:  Error = 0.425517
# Epoch 9269:  Error = 0.425434
# Epoch 9270:  Error = 0.425351
# Epoch 9271:  Error = 0.425269
# Epoch 9272:  Error = 0.425186
# Epoch 9273:  Error = 0.425103
# Epoch 9274:  Error = 0.425020
# Epoch 9275:  Error = 0.424937
# Epoch 9276:  Error = 0.424855
# Epoch 9277:  Error = 0.424772
# Epoch 9278:  Error = 0.424689
# Epoch 9279:  Error = 0.424607
# Epoch 9280:  Error = 0.424524
# Epoch 9281:  Error = 0.424441
# Epoch 9282:  Error = 0.424359
# Epoch 9283:  Error = 0.424276
# Epoch 9284:  Error = 0.424194
# Epoch 9285:  Error = 0.424111
# Epoch 9286:  Error = 0.424029
# Epoch 9287:  Error = 0.423946
# Epoch 9288:  Error = 0.423864
# Epoch 9289:  Error = 0.423781
# Epoch 9290:  Error = 0.423699
# Epoch 9291:  Error = 0.423616
# Epoch 9292:  Error = 0.423534
# Epoch 9293:  Error = 0.423451
# Epoch 9294:  Error = 0.423369
# Epoch 9295:  Error = 0.423287
# Epoch 9296:  Error = 0.423204
# Epoch 9297:  Error = 0.423122
# Epoch 9298:  Error = 0.423040
# Epoch 9299:  Error = 0.422958
# Epoch 9300:  Error = 0.422875
# Epoch 9301:  Error = 0.422793
# Epoch 9302:  Error = 0.422711
# Epoch 9303:  Error = 0.422629
# Epoch 9304:  Error = 0.422547
# Epoch 9305:  Error = 0.422464
# Epoch 9306:  Error = 0.422382
# Epoch 9307:  Error = 0.422300
# Epoch 9308:  Error = 0.422218
# Epoch 9309:  Error = 0.422136
# Epoch 9310:  Error = 0.422054
# Epoch 9311:  Error = 0.421972
# Epoch 9312:  Error = 0.421890
# Epoch 9313:  Error = 0.421808
# Epoch 9314:  Error = 0.421726
# Epoch 9315:  Error = 0.421644
# Epoch 9316:  Error = 0.421562
# Epoch 9317:  Error = 0.421480
# Epoch 9318:  Error = 0.421398
# Epoch 9319:  Error = 0.421317
# Epoch 9320:  Error = 0.421235
# Epoch 9321:  Error = 0.421153
# Epoch 9322:  Error = 0.421071
# Epoch 9323:  Error = 0.420989
# Epoch 9324:  Error = 0.420908
# Epoch 9325:  Error = 0.420826
# Epoch 9326:  Error = 0.420744
# Epoch 9327:  Error = 0.420663
# Epoch 9328:  Error = 0.420581
# Epoch 9329:  Error = 0.420499
# Epoch 9330:  Error = 0.420418
# Epoch 9331:  Error = 0.420336
# Epoch 9332:  Error = 0.420254
# Epoch 9333:  Error = 0.420173
# Epoch 9334:  Error = 0.420091
# Epoch 9335:  Error = 0.420010
# Epoch 9336:  Error = 0.419928
# Epoch 9337:  Error = 0.419847
# Epoch 9338:  Error = 0.419765
# Epoch 9339:  Error = 0.419684
# Epoch 9340:  Error = 0.419602
# Epoch 9341:  Error = 0.419521
# Epoch 9342:  Error = 0.419440
# Epoch 9343:  Error = 0.419358
# Epoch 9344:  Error = 0.419277
# Epoch 9345:  Error = 0.419196
# Epoch 9346:  Error = 0.419114
# Epoch 9347:  Error = 0.419033
# Epoch 9348:  Error = 0.418952
# Epoch 9349:  Error = 0.418870
# Epoch 9350:  Error = 0.418789
# Epoch 9351:  Error = 0.418708
# Epoch 9352:  Error = 0.418627
# Epoch 9353:  Error = 0.418546
# Epoch 9354:  Error = 0.418464
# Epoch 9355:  Error = 0.418383
# Epoch 9356:  Error = 0.418302
# Epoch 9357:  Error = 0.418221
# Epoch 9358:  Error = 0.418140
# Epoch 9359:  Error = 0.418059
# Epoch 9360:  Error = 0.417978
# Epoch 9361:  Error = 0.417897
# Epoch 9362:  Error = 0.417816
# Epoch 9363:  Error = 0.417735
# Epoch 9364:  Error = 0.417654
# Epoch 9365:  Error = 0.417573
# Epoch 9366:  Error = 0.417492
# Epoch 9367:  Error = 0.417411
# Epoch 9368:  Error = 0.417330
# Epoch 9369:  Error = 0.417250
# Epoch 9370:  Error = 0.417169
# Epoch 9371:  Error = 0.417088
# Epoch 9372:  Error = 0.417007
# Epoch 9373:  Error = 0.416926
# Epoch 9374:  Error = 0.416846
# Epoch 9375:  Error = 0.416765
# Epoch 9376:  Error = 0.416684
# Epoch 9377:  Error = 0.416604
# Epoch 9378:  Error = 0.416523
# Epoch 9379:  Error = 0.416442
# Epoch 9380:  Error = 0.416362
# Epoch 9381:  Error = 0.416281
# Epoch 9382:  Error = 0.416200
# Epoch 9383:  Error = 0.416120
# Epoch 9384:  Error = 0.416039
# Epoch 9385:  Error = 0.415959
# Epoch 9386:  Error = 0.415878
# Epoch 9387:  Error = 0.415798
# Epoch 9388:  Error = 0.415717
# Epoch 9389:  Error = 0.415637
# Epoch 9390:  Error = 0.415557
# Epoch 9391:  Error = 0.415476
# Epoch 9392:  Error = 0.415396
# Epoch 9393:  Error = 0.415315
# Epoch 9394:  Error = 0.415235
# Epoch 9395:  Error = 0.415155
# Epoch 9396:  Error = 0.415074
# Epoch 9397:  Error = 0.414994
# Epoch 9398:  Error = 0.414914
# Epoch 9399:  Error = 0.414834
# Epoch 9400:  Error = 0.414753
# Epoch 9401:  Error = 0.414673
# Epoch 9402:  Error = 0.414593
# Epoch 9403:  Error = 0.414513
# Epoch 9404:  Error = 0.414433
# Epoch 9405:  Error = 0.414353
# Epoch 9406:  Error = 0.414272
# Epoch 9407:  Error = 0.414192
# Epoch 9408:  Error = 0.414112
# Epoch 9409:  Error = 0.414032
# Epoch 9410:  Error = 0.413952
# Epoch 9411:  Error = 0.413872
# Epoch 9412:  Error = 0.413792
# Epoch 9413:  Error = 0.413712
# Epoch 9414:  Error = 0.413632
# Epoch 9415:  Error = 0.413552
# Epoch 9416:  Error = 0.413472
# Epoch 9417:  Error = 0.413393
# Epoch 9418:  Error = 0.413313
# Epoch 9419:  Error = 0.413233
# Epoch 9420:  Error = 0.413153
# Epoch 9421:  Error = 0.413073
# Epoch 9422:  Error = 0.412993
# Epoch 9423:  Error = 0.412914
# Epoch 9424:  Error = 0.412834
# Epoch 9425:  Error = 0.412754
# Epoch 9426:  Error = 0.412675
# Epoch 9427:  Error = 0.412595
# Epoch 9428:  Error = 0.412515
# Epoch 9429:  Error = 0.412436
# Epoch 9430:  Error = 0.412356
# Epoch 9431:  Error = 0.412276
# Epoch 9432:  Error = 0.412197
# Epoch 9433:  Error = 0.412117
# Epoch 9434:  Error = 0.412038
# Epoch 9435:  Error = 0.411958
# Epoch 9436:  Error = 0.411879
# Epoch 9437:  Error = 0.411799
# Epoch 9438:  Error = 0.411720
# Epoch 9439:  Error = 0.411640
# Epoch 9440:  Error = 0.411561
# Epoch 9441:  Error = 0.411481
# Epoch 9442:  Error = 0.411402
# Epoch 9443:  Error = 0.411323
# Epoch 9444:  Error = 0.411243
# Epoch 9445:  Error = 0.411164
# Epoch 9446:  Error = 0.411085
# Epoch 9447:  Error = 0.411005
# Epoch 9448:  Error = 0.410926
# Epoch 9449:  Error = 0.410847
# Epoch 9450:  Error = 0.410768
# Epoch 9451:  Error = 0.410688
# Epoch 9452:  Error = 0.410609
# Epoch 9453:  Error = 0.410530
# Epoch 9454:  Error = 0.410451
# Epoch 9455:  Error = 0.410372
# Epoch 9456:  Error = 0.410293
# Epoch 9457:  Error = 0.410214
# Epoch 9458:  Error = 0.410134
# Epoch 9459:  Error = 0.410055
# Epoch 9460:  Error = 0.409976
# Epoch 9461:  Error = 0.409897
# Epoch 9462:  Error = 0.409818
# Epoch 9463:  Error = 0.409739
# Epoch 9464:  Error = 0.409660
# Epoch 9465:  Error = 0.409582
# Epoch 9466:  Error = 0.409503
# Epoch 9467:  Error = 0.409424
# Epoch 9468:  Error = 0.409345
# Epoch 9469:  Error = 0.409266
# Epoch 9470:  Error = 0.409187
# Epoch 9471:  Error = 0.409108
# Epoch 9472:  Error = 0.409030
# Epoch 9473:  Error = 0.408951
# Epoch 9474:  Error = 0.408872
# Epoch 9475:  Error = 0.408793
# Epoch 9476:  Error = 0.408715
# Epoch 9477:  Error = 0.408636
# Epoch 9478:  Error = 0.408557
# Epoch 9479:  Error = 0.408479
# Epoch 9480:  Error = 0.408400
# Epoch 9481:  Error = 0.408321
# Epoch 9482:  Error = 0.408243
# Epoch 9483:  Error = 0.408164
# Epoch 9484:  Error = 0.408086
# Epoch 9485:  Error = 0.408007
# Epoch 9486:  Error = 0.407929
# Epoch 9487:  Error = 0.407850
# Epoch 9488:  Error = 0.407772
# Epoch 9489:  Error = 0.407693
# Epoch 9490:  Error = 0.407615
# Epoch 9491:  Error = 0.407536
# Epoch 9492:  Error = 0.407458
# Epoch 9493:  Error = 0.407379
# Epoch 9494:  Error = 0.407301
# Epoch 9495:  Error = 0.407223
# Epoch 9496:  Error = 0.407144
# Epoch 9497:  Error = 0.407066
# Epoch 9498:  Error = 0.406988
# Epoch 9499:  Error = 0.406910
# Epoch 9500:  Error = 0.406831
# Epoch 9501:  Error = 0.406753
# Epoch 9502:  Error = 0.406675
# Epoch 9503:  Error = 0.406597
# Epoch 9504:  Error = 0.406519
# Epoch 9505:  Error = 0.406440
# Epoch 9506:  Error = 0.406362
# Epoch 9507:  Error = 0.406284
# Epoch 9508:  Error = 0.406206
# Epoch 9509:  Error = 0.406128
# Epoch 9510:  Error = 0.406050
# Epoch 9511:  Error = 0.405972
# Epoch 9512:  Error = 0.405894
# Epoch 9513:  Error = 0.405816
# Epoch 9514:  Error = 0.405738
# Epoch 9515:  Error = 0.405660
# Epoch 9516:  Error = 0.405582
# Epoch 9517:  Error = 0.405504
# Epoch 9518:  Error = 0.405426
# Epoch 9519:  Error = 0.405348
# Epoch 9520:  Error = 0.405271
# Epoch 9521:  Error = 0.405193
# Epoch 9522:  Error = 0.405115
# Epoch 9523:  Error = 0.405037
# Epoch 9524:  Error = 0.404959
# Epoch 9525:  Error = 0.404882
# Epoch 9526:  Error = 0.404804
# Epoch 9527:  Error = 0.404726
# Epoch 9528:  Error = 0.404649
# Epoch 9529:  Error = 0.404571
# Epoch 9530:  Error = 0.404493
# Epoch 9531:  Error = 0.404416
# Epoch 9532:  Error = 0.404338
# Epoch 9533:  Error = 0.404260
# Epoch 9534:  Error = 0.404183
# Epoch 9535:  Error = 0.404105
# Epoch 9536:  Error = 0.404028
# Epoch 9537:  Error = 0.403950
# Epoch 9538:  Error = 0.403873
# Epoch 9539:  Error = 0.403795
# Epoch 9540:  Error = 0.403718
# Epoch 9541:  Error = 0.403640
# Epoch 9542:  Error = 0.403563
# Epoch 9543:  Error = 0.403486
# Epoch 9544:  Error = 0.403408
# Epoch 9545:  Error = 0.403331
# Epoch 9546:  Error = 0.403253
# Epoch 9547:  Error = 0.403176
# Epoch 9548:  Error = 0.403099
# Epoch 9549:  Error = 0.403022
# Epoch 9550:  Error = 0.402944
# Epoch 9551:  Error = 0.402867
# Epoch 9552:  Error = 0.402790
# Epoch 9553:  Error = 0.402713
# Epoch 9554:  Error = 0.402635
# Epoch 9555:  Error = 0.402558
# Epoch 9556:  Error = 0.402481
# Epoch 9557:  Error = 0.402404
# Epoch 9558:  Error = 0.402327
# Epoch 9559:  Error = 0.402250
# Epoch 9560:  Error = 0.402173
# Epoch 9561:  Error = 0.402096
# Epoch 9562:  Error = 0.402019
# Epoch 9563:  Error = 0.401942
# Epoch 9564:  Error = 0.401865
# Epoch 9565:  Error = 0.401788
# Epoch 9566:  Error = 0.401711
# Epoch 9567:  Error = 0.401634
# Epoch 9568:  Error = 0.401557
# Epoch 9569:  Error = 0.401480
# Epoch 9570:  Error = 0.401403
# Epoch 9571:  Error = 0.401326
# Epoch 9572:  Error = 0.401249
# Epoch 9573:  Error = 0.401173
# Epoch 9574:  Error = 0.401096
# Epoch 9575:  Error = 0.401019
# Epoch 9576:  Error = 0.400942
# Epoch 9577:  Error = 0.400866
# Epoch 9578:  Error = 0.400789
# Epoch 9579:  Error = 0.400712
# Epoch 9580:  Error = 0.400635
# Epoch 9581:  Error = 0.400559
# Epoch 9582:  Error = 0.400482
# Epoch 9583:  Error = 0.400406
# Epoch 9584:  Error = 0.400329
# Epoch 9585:  Error = 0.400252
# Epoch 9586:  Error = 0.400176
# Epoch 9587:  Error = 0.400099
# Epoch 9588:  Error = 0.400023
# Epoch 9589:  Error = 0.399946

# %% [markdown]
# ### Test du XOR

# %%
def predict(w1, w2, b1, b2, input):
    
    out1 = sigmoid(np.dot(weights1, input) + bias1)
    output = sigmoid(np.dot(weights2, out1) + bias2)
    if output >= 0.5:
        print("The prediction for:", [i[0] for i in input], "is", 1)
    else:
        print("The prediction for:", [i[0] for i in input], "is", 0)

# %%
test_xor = np.asarray([[-1], [-1]])
predict(weights1, weights2, bias1, bias2, test_xor)
# Out:
# The prediction for: [-1, -1] is 0

# %% [markdown]
# **Optional questions**
#
# 2. *Weight decay* constraint
#
# As nothing constrains the weights in the network, we can note that usually all weights vector given a multiplicative factor might be equivalent, which can stall the learning (and lead to exploding weights). The *weight decay* allows to regularize the learning by penalizing weights with a too wide amplitude. The idea is to add this constraint as a term to the final loss (which leads to an indirect "pressure" on the learning process. Therefore, the final loss will be defined as
#
# $$
# \begin{equation}
# \mathcal{L}_{final}=\mathcal{L_D} + \lambda \sum_{l} \sum_{i} \sum_{j} \left( W_{ij}^{l} \right)^{2}
# \end{equation}
# $$
#
# where the parameter $\lambda$ controls the relative importance of the two terms.
#
# 3. *Momentum* in learning
#
# Usually, in complex problems, the gradient can be very noisy and, therefore, the learning might oscillate widely. In order to reduce this problem, we can *smooth* the different gradient updates by retaining the values of the gradient at each iteration and then performing an update based on the latest gradient $\delta_{i}^{t}$ and the gradient at the previous iteration $\delta_{i}^{t-1}$. Therefore, a gradient update is applied as
#
# $$
# \begin{equation}
# \delta_{final}^{t} = \delta_{i}^{t} + m.\delta_{i}^{t-1}
# \end{equation}
# $$
#
# with $m$ the momentum parameter, which control the amount of gradient smoothing.

# %% [markdown]
# ## 3-layer audio classification
#
# Finally, we will attack a complete audio classification problem and try to perform neural network learning on a set of audio files. The data structure will be the same as the one used for parts 1 and 2. As discussed during the courses, even though a 2-layer neural network can provide non-linear boundaries, it can not perform "holes" inside those regions. In order to obtain an improved classification, we will now rely on a 3-layer neural network. The modification to the code of section 3.2 should be minimal, as the back-propagation will be similar for the new layer as one of the two others. We do not develop the math here as it is simply a re-application of the previous rules with an additional layer (which derivatives you should have generalized in the previous exercise).
#
# However, up until now, we only performed *binary classification* problems, but this time we need to obtain a decision rule for multiple classes. Therefore, we cannot rely on simply computing the distance between desired patterns and the obtained binary value. The idea here is to rely on the *softmax regression*, by considering classes as a vector of probabilities. The desired answers will therefore be considered as a set of *probabilities*, where the desired class is $1$ and the others are $0$ (called *one-hot* representation). Then, the cost function will rely on the softmax formulation
#
# $$
# \begin{equation}
# \mathcal{L_D}(\theta) = - \frac{1}{m} \left[ \sum_{i=1}^{m} \sum_{j=1}^{k} 1\left\{y^{(i)} = j\right\} log \frac{e^{\theta_{j}^{T} x^{(i)}}}{\sum_{l=1}^{k} e^{ \theta_{l}^{T} x^{(i)} }}  \right]
# \end{equation}
# $$
#
# Therefore, we compute the output of the softmax by taking
#
# $$
# \begin{equation}
# p(y^{(i)} = j | x^{(i)}; \theta) = \frac{e^{\theta_{j}^{T} x^{(i)}}}{\sum_{l=1}^{k} e^{ \theta_{l}^{T} x^{(i)}} }
# \end{equation}
# $$
#
# By taking derivatives, we can show that the gradient of the softmax layer is
#
# $$
# \begin{equation}
# \nabla_{\theta_{j}} \mathcal{L_D}(\theta) = - \frac{1}{m} \sum_{i=1}^{m}{ \left[ x^{(i)} \left( 1\{ y^{(i)} = j\}  - p(y^{(i)} = j \mid x^{(i)}, \theta) \right) \right]}
# \end{equation}
# $$

# %% [markdown]
# ### Sweet activation functions
#
# As discussed in the course, the interest of stacking layers is that there is an _activation function_, which allows non-linear interactions between the dimensions (and avoids to only compute a single huge affine transform). Although the `sigmoid` function has been historically the most used, there has been some large developments since. Notably the `ReLU` (Rectified Linear Unit) is one of the major difference in modern networks (we will see more about that in a later course)

# %%
# Function for computing the Sigmoid activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def dsigmoid(a):
    return a * (1.0 - a)

# Function for computing the ReLU activation
def relu(x):
    return np.maximum(0, x)

def drelu(x):
    return 1 / (1 + np.exp(-x))

# Function for computing the Tanh activation
def tanh(x):
    return np.tanh(x)

def dtanh(x): 
    return np.cosh(x) ^ -2

# %% [markdown]
# Here, we plot some simple examples of what these activation functions look like. You can try to rely on these functions in your previous training code and witness the differences in training.

# %%
from helper_plot import prep_plots, finalize_plots

funcs = [('sigmoid',sigmoid,'red'), ('tanh',tanh,'orange'), ('relu',relu,'yellow')]
axes = prep_plots([funcs[0][0], funcs[1][0], funcs[2][0]], fig_size=(18,5), fig_num=1)
x_plot = np.linspace(-5,5,100)
np.maximum(0, x_plot)

for f in range(3):
    axes[f].plot(x_plot, funcs[f][1](x_plot), color=funcs[f][2], linewidth=4, label=funcs[f][0])
    
finalize_plots(axes, fig_title="Activation functions")

# %% [markdown]
# ## Coding the whole network from scratch
#
# You should now have all the tools necessary to apply neural networks from scratch to a more complex problem. In the following exercise, we simply removed any guideline code, and you need to code all the procedure for training a NN and **apply it to audio data**. You will use the spectral features discussed in the previous exercise as an input.
#
# ***
#
# **Exercise**
#
#   1. Based on the previous neural network, upgrade the code to a 3-layer neural network
#   2. Implement the *softmax regression* on top of your 3-layer network
#   3. Use the provided code to perform classification on a pre-defined set of features
#   4. As previously, change the set of features to assess their different accuracies
#   5. Evaluate the neural network accuracy for all features combinations
#   6. What happens if the learning rate is too large ? What is this phenomenon ?
#   7. (Optional) Perform a more advanced visualization of the learning process.
#
# ***

# %%
# Iterate for a fixed number of iterations
for epoch in range(500):
    
    ######################
    # YOUR CODE GOES HERE
    ######################
    
    print('Epoch %3d:  Error = %f\n' % epoch, TSS)
    if TSS < TSS_Limit:
        break
plot_boundary(np.concatenate(bias1, weights1), epoch, '-')

# %% [markdown]
# ## Using Pytorch to enjoy life
#
# Up to now, we have been writing every operations by ourselves (in order to better understand the mathematics behind NN). However, there exists of course some simplifying libraries that provide large simplifications to this question.
#
# One of the most powerful and complete library of this sort is `Pytorch`, which has been developed for several years (even prior to the recent boom of deep learning). `Pytorch` provides a large set of pre-coded layers, but also **computational graphs** and **autograd**, which are very powerful paradigms allowing to define complex operators and automatically taking derivatives.
#
# ### Defining our network
#
# When building neural networks we frequently think of arranging the computation into layers, some of which have learnable parameters which will be optimized during learning. In `PyTorch`, the `nn` package provides higher-level abstractions over raw computational graphs that are useful for building neural networks. The `nn` package defines a set of `Modules`, which are roughly equivalent to neural network layers. A `Module` receives input `Tensors` and computes output `Tensors`, but may also hold internal state such as `Tensors` containing learnable parameters. The nn package also defines a set of useful loss functions that are commonly used when training neural networks.
#
# In the following example, we use the `nn` package to show how easy it is to instantiate our previous three-layers network

# %%
import torch

# Define the input dimensions
in_size = 1000

# Number of neurons in a layer
hidden_size = 100

# Output (target) dimension
output_size = 10

# Use the nn package to define our model and loss function.
model = torch.nn.Sequential(
    torch.nn.Linear(in_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, output_size),
    torch.nn.Softmax(dim=1)
)

# %% [markdown]
# ### Optimizing the network
#
# Up to this point we have updated the weights of our models by manually performing the gradient descent algorithm (changing the parameters vectors). Although this is not a huge burden for simple optimization algorithms like stochastic gradient descent, in practice we often train neural networks using more sophisticated optimizers like AdaGrad, RMSProp or Adam (that we will see later in this course)
#
# The `optim` package in PyTorch abstracts the idea of an optimization algorithm and provides implementations of commonly used optimization algorithms, and greatly simplfies the training loop associated with training a neural network.
#
# For the sake of presentation we will use random inputs $\mathbf{x}$ that should be matched with random outputs $\mathbf{y}$

# %%
batch_size = 64
N = 20

# Create random Tensors to hold inputs and outputs
x = torch.randn(N, in_size)
y = torch.randn(N, output_size)

# %% [markdown]
# In the following example we optimize the model using the Adam algorithm provided by the `optim` package, based on a `MSE` loss.

# %%
# Learning rate
learning_rate = 1e-4

# Loss function that we will use
loss_fn = torch.nn.MSELoss(reduction='sum')

# Optimizer to fit the weights of the network
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
for t in range(500):
    # Forward pass: compute predicted y by passing x to the model.
    y_pred = model(x)
    
    # Compute the loss.
    loss = loss_fn(y_pred, y)
    
    # Before the backward pass, zero all of the network gradients
    optimizer.zero_grad()
    
    # Backward pass: compute gradient of the loss with respect to parameters
    loss.backward()
    
    # Calling the step function to update the parameters
    optimizer.step()

# %%
y_test = model(torch.randn(12, in_size))
y_test
# Out:
# tensor([[0.0230, 0.0321, 0.0208, 0.0169, 0.0191, 0.0454, 0.0659, 0.2859, 0.0700,
#          0.4208],
#         [0.0780, 0.1005, 0.0213, 0.0330, 0.0203, 0.0325, 0.0650, 0.1052, 0.0565,
#          0.4877],
#         [0.0419, 0.2078, 0.0171, 0.0222, 0.0128, 0.0115, 0.2350, 0.0696, 0.0731,
#          0.3089],
#         [0.0828, 0.0503, 0.0504, 0.1097, 0.0598, 0.0772, 0.1811, 0.1211, 0.0758,
#          0.1919],
#         [0.0535, 0.1578, 0.0598, 0.0604, 0.0801, 0.1051, 0.1834, 0.1655, 0.0755,
#          0.0590],
#         [0.1857, 0.0579, 0.0871, 0.0288, 0.0188, 0.0431, 0.0784, 0.0655, 0.0756,
#          0.3591],
#         [0.0583, 0.1422, 0.0549, 0.0303, 0.0272, 0.0350, 0.1092, 0.2245, 0.0598,
#          0.2587],
#         [0.0489, 0.0603, 0.4011, 0.0306, 0.0783, 0.0398, 0.0937, 0.1184, 0.0249,
#          0.1040],
#         [0.0432, 0.0832, 0.0506, 0.0113, 0.0287, 0.0605, 0.1033, 0.4115, 0.0562,
#          0.1516],
#         [0.1145, 0.0783, 0.0493, 0.0466, 0.0224, 0.0411, 0.1314, 0.1282, 0.0406,
#          0.3474],
#         [0.0171, 0.1240, 0.0558, 0.0136, 0.0264, 0.0302, 0.0504, 0.5472, 0.0465,
#          0.0887],
#         [0.2332, 0.0306, 0.1558, 0.0369, 0.0289, 0.1300, 0.0609, 0.0368, 0.0216,
#          0.2652]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# ## Using Pytorch to classify audio
#
# Now that we know the main components of `Pytorch` to define and optimize networks, your assignement is to define a complete classification problem from audio data, by relying on this toolbox
#
# ***
#
# **Exercise**
#
#   1. Use `Pytorch` to define a model for audio classification
#   2. Import the audio features dataset and check that your model produces an output
#   3. Write the optimization loop (think carefully about the _loss function_
#   4. As previously, change the set of features to assess their different accuracies
#   5. Think of how you could use more complex features (time series, audio, STFT) to classify your data
#
# ***

# %%
import torch
from helper_data import import_dataset
from helper_data import compute_transforms

class_path = 'data/classification';

data_struct = import_dataset(class_path, 'classification');
data_struct_transform = compute_transforms(data_struct);
# Out:
#     - Importing dataset data/classification.
#
#     - Performing transforms.

# %%
X = data_struct["spectrum_mel"]
Y_label = data_struct["classes"]

# %%
# Define the input dimensions - number of channel... for an image it is 3 (40x40x3) for audio 1 or 2: mono/stereo (sr*duration, 1/2)
in_size = 1

# Number of neurons in a layer
hidden_size = 100

# Output (target) dimension - number of class label
output_size = 16

# Definition of the neural networks
model = torch.nn.Sequential(
    torch.nn.Linear(in_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, output_size),
    torch.nn.Softmax(dim=1)
)
